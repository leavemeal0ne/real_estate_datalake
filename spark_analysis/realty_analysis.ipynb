# %%
# %fs ls 's3://realty-datalake/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>s3://realty-datalake/realty_data_2025-10-31.csv</td><td>realty_data_2025-10-31.csv</td><td>34106</td><td>1764241393000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-01.csv</td><td>realty_data_2025-11-01.csv</td><td>37087</td><td>1764241150000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-02.csv</td><td>realty_data_2025-11-02.csv</td><td>27836</td><td>1764240819000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-03.csv</td><td>realty_data_2025-11-03.csv</td><td>53019</td><td>1764242335000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-04.csv</td><td>realty_data_2025-11-04.csv</td><td>57158</td><td>1764243900000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-05.csv</td><td>realty_data_2025-11-05.csv</td><td>52778</td><td>1764243980000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-06.csv</td><td>realty_data_2025-11-06.csv</td><td>52408</td><td>1764244746000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-07.csv</td><td>realty_data_2025-11-07.csv</td><td>50985</td><td>1764245384000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-08.csv</td><td>realty_data_2025-11-08.csv</td><td>37956</td><td>1764246052000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-09.csv</td><td>realty_data_2025-11-09.csv</td><td>26697</td><td>1764245834000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-10.csv</td><td>realty_data_2025-11-10.csv</td><td>73423</td><td>1764248613000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-11.csv</td><td>realty_data_2025-11-11.csv</td><td>60482</td><td>1764248893000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-12.csv</td><td>realty_data_2025-11-12.csv</td><td>70158</td><td>1764249267000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-13.csv</td><td>realty_data_2025-11-13.csv</td><td>64784</td><td>1764249214000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-14.csv</td><td>realty_data_2025-11-14.csv</td><td>65005</td><td>1764207876000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-15.csv</td><td>realty_data_2025-11-15.csv</td><td>60528</td><td>1764207895000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-16.csv</td><td>realty_data_2025-11-16.csv</td><td>51555</td><td>1764207908000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-17.csv</td><td>realty_data_2025-11-17.csv</td><td>116931</td><td>1764207917000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-18.csv</td><td>realty_data_2025-11-18.csv</td><td>108315</td><td>1764207927000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-19.csv</td><td>realty_data_2025-11-19.csv</td><td>119752</td><td>1764207941000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-20.csv</td><td>realty_data_2025-11-20.csv</td><td>98496</td><td>1764207951000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-21.csv</td><td>realty_data_2025-11-21.csv</td><td>103063</td><td>1764207961000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-22.csv</td><td>realty_data_2025-11-22.csv</td><td>80910</td><td>1764207971000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-23.csv</td><td>realty_data_2025-11-23.csv</td><td>92818</td><td>1764209007000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-24.csv</td><td>realty_data_2025-11-24.csv</td><td>219052</td><td>1764207983000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-25.csv</td><td>realty_data_2025-11-25.csv</td><td>158721</td><td>1764233866000</td></tr><tr><td>s3://realty-datalake/realty_data_2025-11-26.csv</td><td>realty_data_2025-11-26.csv</td><td>215629</td><td>1764211343000</td></tr></tbody></table></div>

# %%
from pyspark.sql.types import *

# %%
data_schema = StructType([
    StructField('id', LongType(), True), 
    StructField('price', IntegerType(), True), 
    StructField('location', StringType(), True), 
    StructField('count_of_rooms', IntegerType(), True), 
    StructField('realty_floor', IntegerType(), True), 
    StructField('realty_max_floors', IntegerType(), True), 
    StructField('main_room_square', IntegerType(), True), 
    StructField('kitchen_square', IntegerType(), True), 
    StructField('bathroom_square', IntegerType(), True), 
    StructField('discovery_date', DateType(), True), 
    StructField('property_list', StringType(), True),   
    StructField('furniture_list', StringType(), True)   
])

# %%
df = spark.read.csv('s3://realty-datalake/realty_data_2025*', header=True, schema=data_schema)

# %%
display(df.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>price</th><th>location</th><th>count_of_rooms</th><th>realty_floor</th><th>realty_max_floors</th><th>main_room_square</th><th>kitchen_square</th><th>bathroom_square</th><th>discovery_date</th><th>property_list</th><th>furniture_list</th></tr></thead><tbody><tr><td>3963091377</td><td>55314</td><td>Київ - Печерський - Нова забудова - ЖК Tetris Hall - Ділова вулиця - 1/2</td><td>2</td><td>7</td><td>25</td><td>60</td><td>20</td><td>25</td><td>2025-11-24</td><td>['спец. проєкт', 'індивідуальне Опалення', '2016 Рік будівництва', 'монолітно-каркасна']</td><td>['Телевізор', 'Кабельне ТБ', 'Шафа', 'Ліжко', 'Кондиціонер', 'Пральна машина', 'Душова кабіна', 'Холодильник', 'Мікрохвильовка', 'Посудомийна машина', 'Посуд', 'Лічильники']</td></tr><tr><td>3961963663</td><td>38295</td><td>Київ - Дарницький - Позняки - Урлівська вулиця - 23-Б</td><td>2</td><td>25</td><td>25</td><td>75</td><td>null</td><td>30</td><td>2025-11-24</td><td>['спец. проєкт', 'централізоване Опалення', '2013 Рік будівництва', 'монолітно-каркасна']</td><td>['Кабельне ТБ', 'Пральна машина', 'Холодильник', 'Телевізор', 'Ліжко', 'Посудомийна машина', 'Сигналізація', 'Кондиціонер', 'Душ', 'Шафа', 'Лічильники']</td></tr><tr><td>3962651579</td><td>20000</td><td>Чайки - ЖК Чайка - вулиця Валерія Лобановського - 13</td><td>2</td><td>15</td><td>16</td><td>77</td><td>null</td><td>30</td><td>2025-11-24</td><td>['спец. проєкт', 'централізоване Опалення', '2016 Рік будівництва', 'цегляна']</td><td>['Пральна машина', 'Холодильник', 'Телевізор', 'Праска', 'Посудомийна машина', 'Кондиціонер', 'Мікрохвильовка']</td></tr><tr><td>3963891008</td><td>11500</td><td>Київ - Святошинський - Біличі - Чорнобильська вулиця - 14</td><td>1</td><td>10</td><td>12</td><td>36</td><td>null</td><td>8</td><td>2025-11-24</td><td>['серія Т', 'централізоване Опалення', '1989 Рік будівництва', 'утеплена панель']</td><td>['Пральна машина', 'Холодильник']</td></tr><tr><td>3963352292</td><td>148924</td><td>Київ - Печерський - Нова забудова - ЖК Tetris Hall - Ділова вулиця - 1/2</td><td>3</td><td>15</td><td>26</td><td>130</td><td>70</td><td>20</td><td>2025-11-24</td><td>['спец. проєкт', 'індивідуальне Опалення', '2016 Рік будівництва', 'монолітно-каркасна']</td><td>[]</td></tr></tbody></table></div>

# %%
display(df.count())
# Out:
# 5675

# %%
df = df.dropDuplicates(['id'])

# %%
display(df.count())
# Out:
# 5608

# %%
from pyspark.sql import functions as F

# %%
df_transformed = (
    df
    .withColumn("property_list",
                F.from_json(
                    F.regexp_replace("property_list", "'", '"'),
                    ArrayType(StringType())
                )
    )
    .withColumn("furniture_list",
                F.from_json(
                    F.regexp_replace("furniture_list", "'", '"'),
                    ArrayType(StringType())
                )
    )
)

# %%
df_transformed.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- location: string (nullable = true)
#  |-- count_of_rooms: integer (nullable = true)
#  |-- realty_floor: integer (nullable = true)
#  |-- realty_max_floors: integer (nullable = true)
#  |-- main_room_square: integer (nullable = true)
#  |-- kitchen_square: integer (nullable = true)
#  |-- bathroom_square: integer (nullable = true)
#  |-- discovery_date: date (nullable = true)
#  |-- property_list: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- furniture_list: array (nullable = true)
#  |    |-- element: string (containsNull = true)

# %%
display(df_transformed.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>price</th><th>location</th><th>count_of_rooms</th><th>realty_floor</th><th>realty_max_floors</th><th>main_room_square</th><th>kitchen_square</th><th>bathroom_square</th><th>discovery_date</th><th>property_list</th><th>furniture_list</th></tr></thead><tbody><tr><td>3970854134</td><td>19999</td><td>Київ - Солом’янський - Караваєві Дачі - вулиця Вадима Гетьмана - 46-А/1</td><td>2</td><td>1</td><td>16</td><td>56</td><td>29</td><td>9</td><td>2025-11-26</td><td>List()</td><td>List(Телевізор, Кабельне ТБ, Праска, Шафа, Підігрів підлоги, Кондиціонер, Пральна машина, Душова кабіна, Холодильник, Мікрохвильовка, Посуд, Лічильники)</td></tr><tr><td>3963294089</td><td>17975</td><td>Київ - Подільський - Виноградар - проспект Європейського Союзу - 92</td><td>3</td><td>3</td><td>9</td><td>70</td><td>null</td><td>8</td><td>2025-11-24</td><td>List(чеський проєкт, централізоване Опалення, 1977 Рік будівництва, панельна)</td><td>List(Кондиціонер)</td></tr><tr><td>3964717615</td><td>10500</td><td>Київ - Святошинський - Борщагівка - вулиця Гната Юри - 1</td><td>1</td><td>6</td><td>9</td><td>29</td><td>null</td><td>6</td><td>2025-11-24</td><td>List(гостинка, централізоване Опалення, 1983 Рік будівництва, цегляна)</td><td>List(Пральна машина, Холодильник)</td></tr><tr><td>3967164509</td><td>16000</td><td>Київ - Солом’янський - вулиця Миколи Шепелєва</td><td>1</td><td>4</td><td>12</td><td>46</td><td>null</td><td>12</td><td>2025-11-25</td><td>List(централізоване Опалення, цегляна)</td><td>List(Пральна машина, Холодильник, Посудомийна машина)</td></tr><tr><td>3963744140</td><td>27990</td><td>Київ - Солом’янський - Відрадний - ЖК Микитська Слобода - вулиця Академіка Шалімова - 35-А</td><td>2</td><td>6</td><td>24</td><td>70</td><td>18</td><td>14</td><td>2025-11-24</td><td>List(спец. проєкт, централізоване Опалення, 2016 Рік будівництва, монолітно-каркасна)</td><td>List()</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import udf

# %%
@udf(returnType=StringType())
def get_kyiv_region_from_location(location):
    region_list = [
        'Голосіївський', 'Дарницький', 
        'Деснянський', 'Дніпровський', 
        'Оболонський', 'Печерський', 
        'Подільський', 'Святошинський', 
        'Солом’янський','Шевченківський']
    for region in region_list:
        if region.lower() in location.lower():
            return region
    return None

# %%
df_realty_data = df_transformed.withColumn("region", get_kyiv_region_from_location("location")).filter(F.col('region').isNotNull())

# %%
display(df_realty_data.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>price</th><th>location</th><th>count_of_rooms</th><th>realty_floor</th><th>realty_max_floors</th><th>main_room_square</th><th>kitchen_square</th><th>bathroom_square</th><th>discovery_date</th><th>property_list</th><th>furniture_list</th><th>region</th></tr></thead><tbody><tr><td>3970854134</td><td>19999</td><td>Київ - Солом’янський - Караваєві Дачі - вулиця Вадима Гетьмана - 46-А/1</td><td>2</td><td>1</td><td>16</td><td>56</td><td>29</td><td>9</td><td>2025-11-26</td><td>List()</td><td>List(Телевізор, Кабельне ТБ, Праска, Шафа, Підігрів підлоги, Кондиціонер, Пральна машина, Душова кабіна, Холодильник, Мікрохвильовка, Посуд, Лічильники)</td><td>Солом’янський</td></tr><tr><td>3963294089</td><td>17975</td><td>Київ - Подільський - Виноградар - проспект Європейського Союзу - 92</td><td>3</td><td>3</td><td>9</td><td>70</td><td>null</td><td>8</td><td>2025-11-24</td><td>List(чеський проєкт, централізоване Опалення, 1977 Рік будівництва, панельна)</td><td>List(Кондиціонер)</td><td>Подільський</td></tr><tr><td>3964717615</td><td>10500</td><td>Київ - Святошинський - Борщагівка - вулиця Гната Юри - 1</td><td>1</td><td>6</td><td>9</td><td>29</td><td>null</td><td>6</td><td>2025-11-24</td><td>List(гостинка, централізоване Опалення, 1983 Рік будівництва, цегляна)</td><td>List(Пральна машина, Холодильник)</td><td>Святошинський</td></tr><tr><td>3967164509</td><td>16000</td><td>Київ - Солом’янський - вулиця Миколи Шепелєва</td><td>1</td><td>4</td><td>12</td><td>46</td><td>null</td><td>12</td><td>2025-11-25</td><td>List(централізоване Опалення, цегляна)</td><td>List(Пральна машина, Холодильник, Посудомийна машина)</td><td>Солом’янський</td></tr><tr><td>3963744140</td><td>27990</td><td>Київ - Солом’янський - Відрадний - ЖК Микитська Слобода - вулиця Академіка Шалімова - 35-А</td><td>2</td><td>6</td><td>24</td><td>70</td><td>18</td><td>14</td><td>2025-11-24</td><td>List(спец. проєкт, централізоване Опалення, 2016 Рік будівництва, монолітно-каркасна)</td><td>List()</td><td>Солом’янський</td></tr></tbody></table></div>

# %%
#df_realty_data.cache()

# %%
df_grouped_by_region_count_of_rooms = df_realty_data\
                                        .groupBy('region','count_of_rooms') \
                                        .agg(F.avg('price').alias('avg_price'),\
                                             F.avg('main_room_square').alias('avg_main_room_square'))\
                                        .withColumn('avg_main_room_square', F.col('avg_main_room_square').cast('integer') )\
                                        .withColumn('avg_price', F.col('avg_price').cast('integer') )\
                                        .orderBy('avg_price','count_of_rooms')
                                        
display(df_grouped_by_region_count_of_rooms)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>region</th><th>count_of_rooms</th><th>avg_price</th><th>avg_main_room_square</th></tr></thead><tbody><tr><td>Деснянський</td><td>1</td><td>9943</td><td>35</td></tr><tr><td>Деснянський</td><td>2</td><td>12944</td><td>55</td></tr><tr><td>Святошинський</td><td>1</td><td>13726</td><td>34</td></tr><tr><td>Дніпровський</td><td>1</td><td>14409</td><td>36</td></tr><tr><td>Оболонський</td><td>1</td><td>15168</td><td>37</td></tr><tr><td>Деснянський</td><td>3</td><td>15803</td><td>77</td></tr><tr><td>Дарницький</td><td>1</td><td>16578</td><td>40</td></tr><tr><td>Солом’янський</td><td>1</td><td>17004</td><td>38</td></tr><tr><td>Святошинський</td><td>2</td><td>17508</td><td>55</td></tr><tr><td>Дніпровський</td><td>2</td><td>18238</td><td>53</td></tr><tr><td>Подільський</td><td>1</td><td>18793</td><td>39</td></tr><tr><td>Деснянський</td><td>4</td><td>20000</td><td>97</td></tr><tr><td>Оболонський</td><td>2</td><td>20053</td><td>56</td></tr><tr><td>Дарницький</td><td>2</td><td>20532</td><td>60</td></tr><tr><td>Святошинський</td><td>3</td><td>20585</td><td>77</td></tr><tr><td>Солом’янський</td><td>2</td><td>21268</td><td>54</td></tr><tr><td>Голосіївський</td><td>1</td><td>22460</td><td>40</td></tr><tr><td>Подільський</td><td>2</td><td>25091</td><td>56</td></tr><tr><td>Шевченківський</td><td>1</td><td>25228</td><td>40</td></tr><tr><td>Дніпровський</td><td>3</td><td>25280</td><td>78</td></tr><tr><td>Оболонський</td><td>3</td><td>25531</td><td>84</td></tr><tr><td>Дарницький</td><td>3</td><td>26422</td><td>83</td></tr><tr><td>Дарницький</td><td>4</td><td>29777</td><td>116</td></tr><tr><td>Шевченківський</td><td>6</td><td>29992</td><td>172</td></tr><tr><td>Шевченківський</td><td>2</td><td>30021</td><td>57</td></tr><tr><td>